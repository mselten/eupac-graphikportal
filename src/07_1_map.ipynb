# %%
import folium
import pandas as pd

coordinative_csv = "../output_csv/bremen_data_v5_2_with_coordinate.csv"
df_artist_with_coordinate = pd.read_csv(coordinative_csv) 
df_artist_with_coordinate["birth year"] = df_artist_with_coordinate["birth year"].astype("Int64")
df_artist_with_coordinate["birth_year_span_start"] = df_artist_with_coordinate["birth_year_span_start"].astype("Int64")

df_artist_with_coordinate.head()
# Out:
#   artistGNDId           artistName (preferred) placeOfBirth  birth year  \
# 0   100076262  Caylus, Anne Claude Philippe de        Paris        1692
# 1   100104401         Dequevauviller, François    Abbeville        1745
# 2   100648916                  Collas, Achille        Paris        1795
# 3   100786294             Porret, Henri Désiré        Lille        1800
# 4   100811833             Kraus, Johann Ulrich     Augsburg        1655
#
#    num_works  birth_year_span_start   latitude  longitude
# 0         24                   1650  48.858890   2.320041
# 1          1                   1700  50.106083   1.833703
# 2          3                   1750  48.858890   2.320041
# 3          6                   1800  50.636565   3.063528
# 4         48                   1650  48.369034  10.897952

# %%
df_artist_with_coordinate["placeOfBirth"].value_counts()
# Out:
# placeOfBirth
# Paris                                         278
# Nürnberg                                     115
# Antwerpen                                      56
# Amsterdam                                      40
# Augsburg                                       31
#                                              ...
# Sedan                                           1
# Rive-de-Gier                                    1
# Vernon <Eure>                                   1
# Maidstone                                       1
# Toul (Dép.Meurthe-et-Moselle) (od. Metz?)      1
# Name: count, Length: 402, dtype: int64

# %%
df_artist_with_coordinate["birth_year_span_start"].value_counts()
# Out:
# birth_year_span_start
# 1800    308
# 1750    192
# 1500    189
# 1700    176
# 1600    159
# 1550    119
# 1850     91
# 1650     79
# 1450     68
# 1400     15
# 4950      2
# 1900      2
# Name: count, dtype: Int64

# %% [markdown]
# Split dataframe to multiple dataframes based on `birth_year_span_start`

# %%
grouped_dfs = {
    year: group for year, group in df_artist_with_coordinate.groupby("birth_year_span_start")
}
print(grouped_dfs.keys())
grouped_dfs[1400].head()
# Out:
# dict_keys([np.int64(1400), np.int64(1450), np.int64(1500), np.int64(1550), np.int64(1600), np.int64(1650), np.int64(1700), np.int64(1750), np.int64(1800), np.int64(1850), np.int64(1900), np.int64(4950)])
#     artistGNDId            artistName (preferred) placeOfBirth  birth year  \
# 35    102359229  Anonym, deutsch, 15. Jahrhundert    Straßburg        1401
# 189  1065633092                       Zoan Andrea       Mantua        1424
# 445   11852786X  Anonym, deutsch, 15. Jahrhundert    Nürnberg        1401
# 563   118563890  Anonym, deutsch, 15. Jahrhundert    Nürnberg        1401
# 578   118577336                  Mantegna, Andrea        Padua        1431
#
#      num_works  birth_year_span_start   latitude  longitude
# 35           3                   1400  48.584614   7.750713
# 189          6                   1400  45.169263  10.670837
# 445          5                   1400  49.453872  11.077298
# 563          5                   1400  49.453872  11.077298
# 578          1                   1400  45.407717  11.873446

# %%
merged_dfs_by_year = {}

for year, group in grouped_dfs.items():
    merged_df = group.groupby("placeOfBirth").agg({
        "artistName (preferred)": lambda x: "; ".join(x.dropna().unique()),
        "placeOfBirth": "count",  # count how many artists per place
        "latitude": "first",
        "longitude": "first"
    }).rename(columns={
        "artistName (preferred)": "artists",
        "placeOfBirth": "artistCount"
    }).reset_index()
    
    merged_dfs_by_year[year] = merged_df

merged_dfs_by_year[1400].head()
# Out:
#      placeOfBirth                                            artists  \
# 0          Colmar  Anonym; Anonym, deutsch; Anonym, deutsch, 15. ...
# 1         Koblenz               Anonym, französisch, 15. Jahrhundert
# 2          Mantua                                        Zoan Andrea
# 3  Markgröningen                   Anonym, deutsch, 15. Jahrhundert
# 4       Nürnberg  Anonym, deutsch, 15. Jahrhundert; Wolgemut, Mi...
#
#    artistCount   latitude  longitude
# 0            5  48.077752   7.357964
# 1            1  50.353328   7.594395
# 2            1  45.169263  10.670837
# 3            1  48.905063   9.080811
# 4            3  49.453872  11.077298

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from branca.element import Template, MacroElement

year_slider = widgets.IntSlider(
    value=min(merged_dfs_by_year.keys()),
    min=1450,
    max=1900,
    step=50, 
    description='Year:'
)

def update_map(year):
    clear_output(wait=True)
    display(year_slider)
    
    df = merged_dfs_by_year[year]

    # Create a new map
    m = folium.Map(location=[50, 10], zoom_start=4)

    # Color based on artist count
    for _, row in df.dropna(subset=["latitude", "longitude"]).iterrows():
        count = row["artistCount"]
        if count > 10:
            color = "darkred"
        elif count >= 5:
            color = "orange"
        elif count >=  3:
            color = "blue"
        else:
            color = "green"

        folium.CircleMarker(
            location=[row["latitude"], row["longitude"]],
            # radius=5 + count * 0.3,
            radius= 6,
            popup=folium.Popup(f"<b>Place of Birth:</b> {row['placeOfBirth']}<br> <b>Artists:</b> {row['artists']}<br><b>Count:</b> {row['artistCount']}", max_width=300),
            color=color,
            fill=True,
            fill_opacity=0.7
        ).add_to(m)
    
    legend_html = """
    {% macro html(this, kwargs) %}
    <div style="
        position: fixed;
        bottom: 50px;
        left: 50px;
        width: 150px;
        height: 120px;
        background-color: white;
        border:2px solid grey;
        z-index:9999;
        font-size:14px;
        padding: 10px;
        ">
        <b>Artist Count</b><br>
        <i style="color:darkred;">●</i> > 10<br>
        <i style="color:orange;">●</i> 5–10<br>
        <i style="color:blue;">●</i> 3–4<br>
        <i style="color:green;">●</i> 1–2<br>
    </div>
    {% endmacro %}
    """
    legend = MacroElement()
    legend._template = Template(legend_html)
    m.get_root().add_child(legend)

    display(m)

# 3. Bind slider to map update
year_slider.observe(lambda change: update_map(change['new']), names='value')

# 4. Display the slider and the first map
display(year_slider)
update_map(year_slider.value)
# Out:
# IntSlider(value=1600, description='Year:', max=1900, min=1450, step=50)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c46598dfb0318d1fecf70b03fd02a8fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c46598dfb0318d1fecf70b03fd02a8fe&quot; &gt;&lt;/div&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 50px;
#         left: 50px;
#         width: 150px;
#         height: 120px;
#         background-color: white;
#         border:2px solid grey;
#         z-index:9999;
#         font-size:14px;
#         padding: 10px;
#         &quot;&gt;
#         &lt;b&gt;Artist Count&lt;/b&gt;&lt;br&gt;
#         &lt;i style=&quot;color:darkred;&quot;&gt;●&lt;/i&gt; &gt; 10&lt;br&gt;
#         &lt;i style=&quot;color:orange;&quot;&gt;●&lt;/i&gt; 5–10&lt;br&gt;
#         &lt;i style=&quot;color:blue;&quot;&gt;●&lt;/i&gt; 3–4&lt;br&gt;
#         &lt;i style=&quot;color:green;&quot;&gt;●&lt;/i&gt; 1–2&lt;br&gt;
#     &lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c46598dfb0318d1fecf70b03fd02a8fe = L.map(
#                 &quot;map_c46598dfb0318d1fecf70b03fd02a8fe&quot;,
#                 {
#                     center: [50.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b18c288e427d2e4c9031f0b0d002cd7f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b18c288e427d2e4c9031f0b0d002cd7f.addTo(map_c46598dfb0318d1fecf70b03fd02a8fe);
#
#
#             var circle_marker_7639968a2992398cd86cd9af8ecd1759 = L.circleMarker(
#                 [50.1060835, 1.8337029],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c46598dfb0318d1fecf70b03fd02a8fe);
#
#
#         var popup_99c837fd9dc980866d45763ec8d32439 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_2ee5318ad87effeb3dffe3a320fcb283 = $(`&lt;div id=&quot;html_2ee5318ad87effeb3dffe3a320fcb283&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Place of Birth:&lt;/b&gt; Abbeville&lt;br&gt; &lt;b&gt;Artists:&lt;/b&gt; Poilly, Nicolas de; Poilly, François de&lt;br&gt;&lt;b&gt;Count:&lt;/b&gt; 2&lt;/div&gt;`)[0];
#                 popup_99c837fd9dc980866d45763ec8d32439.setContent(html_2ee5318ad87effeb3dffe3a320fcb283);
#
#
#
#         circle_marker_7639968a2992398cd86cd9af8ecd1759.bindPopup(popup_99c837fd9dc980866d45763ec8d32439)
#         ;
#
#
#
#
#             var circle_marker_e99e17cb6820004a44b091509f6e5f73 = L.circleMarker(
#                 [52.6008538, 4.8170994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c46598dfb0318d1fecf70b03fd02a8fe);
#
#
#         var popup_8b9421b2d9409b388f97b9eb8cc84874 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_187ef7cc37eaebac1b69bf3b8543db7d = $(`&lt;div id=&quot;html_187ef7cc37eaebac1b69bf3b8543db7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Place of Birth:&lt;/b&gt; Alkmaar&lt;br&gt; &lt;b&gt;Artists:&lt;/b&gt; Anonym, niederländisch, 17. Jahrhundert; Everdingen, Allart van&lt;br&gt;&lt;b&gt;Count:&lt;/b&gt; 2&lt;/div&gt;`)[0];
#                 popup_8b9421b2d9409b388f97b9eb8cc84874.setContent(html_187ef7cc37eaebac1b69bf3b8543db7d);
#
#
#
#         circle_marker_e99e17cb6820004a44b091509f6e5f73.bindPopup(popup_8b9421b2d9409b388f97b9eb8cc84874)
#         ;
#
#
#
#
#             var circle_marker_994c625454f28648ea5b4f996033cc97 = L.circleMarker(
#                 [52.3730796, 4.8924534],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&qu
