# %%
import os
import csv
import pandas as pd
import numpy as np
from lxml import etree

# Directory containing the XML files
folder_path = "../data/bremen/lido"
namespace = {"lido": "http://www.lido-schema.org"}

# Output CSV file path
output_csv = "../output_csv/bremen_output.csv"

# Initialize a list to store all record data
data = []

# Loop through each subfolder in the lido directory
for subfolder in os.listdir(folder_path):
    subfolder_path = os.path.join(folder_path, subfolder)
    if os.path.isdir(subfolder_path):
        # Loop through each XML file in the subfolder
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".xml"):
                filepath = os.path.join(subfolder_path, filename)
                tree = etree.parse(filepath)

                # Fields
                lido_record_id = tree.xpath("string(//lido:lidoRecID)", namespaces=namespace)
                image_urls = tree.xpath("//lido:linkResource/text()", namespaces=namespace)
                types = tree.xpath("//lido:objectWorkType/lido:term/text()", namespaces=namespace)
                materials = tree.xpath("//lido:termMaterialsTech/lido:term/text()", namespaces=namespace)
                display_date = tree.xpath("string(//lido:eventDate/lido:displayDate)", namespaces=namespace)
                earliest_date = tree.xpath("string(//lido:eventDate/lido:date/lido:earliestDate)", namespaces=namespace)
                latest_date = tree.xpath("string(//lido:eventDate/lido:date/lido:latestDate)", namespaces=namespace)
                subjects = tree.xpath("//lido:subjectConcept/lido:term/text()", namespaces=namespace)
                artist_name = tree.xpath("string(//lido:nameActorSet/lido:appellationValue[@lido:pref='preferred'])", namespaces=namespace)
                nationality = tree.xpath("string(//lido:culture/lido:term)", namespaces=namespace)
                role = tree.xpath("string(//lido:roleActor/lido:term)", namespaces=namespace)
                birth = tree.xpath("string(//lido:vitalDatesActor/lido:earliestDate)", namespaces=namespace)
                death = tree.xpath("string(//lido:vitalDatesActor/lido:latestDate)", namespaces=namespace)
                location = tree.xpath("string(//lido:repositoryLocation/lido:namePlaceSet/lido:appellationValue)", namespaces=namespace)
                classifications = tree.xpath("//lido:classification/lido:term/text()", namespaces=namespace)
                titles = tree.xpath("//lido:titleSet/lido:appellationValue/text()", namespaces=namespace)
                rights_statements = tree.xpath("//lido:rightsResource/lido:rightsType/lido:conceptID[@lido:type='http://terminology.lido-schema.org/lido00099']/text()", namespaces=namespace)
                work_id = tree.xpath("string(//lido:workID)", namespaces=namespace)
                repository_name = tree.xpath("//lido:legalBodyName/lido:appellationValue/text()", namespaces=namespace)
                record_id = tree.xpath("string(//lido:recordID)", namespaces=namespace)
                record_links = tree.xpath("//lido:recordInfoLink/text()", namespaces=namespace)
                event_type = tree.xpath("string(//lido:eventType/lido:term)", namespaces=namespace)
                display_materials = tree.xpath("//lido:displayMaterialsTech/text()", namespaces=namespace)
                inscriptions = tree.xpath("//lido:inscriptionDescription/lido:descriptiveNoteValue/text()", namespaces=namespace)
                related_work_notes = tree.xpath("//lido:objectNote/text()", namespaces=namespace)

                data.append({
                    "lidoRecordId": lido_record_id,
                    "imageUrl": "; ".join(image_urls),
                    "type": "; ".join(types),
                    "material": "; ".join(materials),
                    "displayDate": display_date,
                    "earliestDate": earliest_date,
                    "latestDate": latest_date,
                    "subject": "; ".join(subjects),
                    "artistName": artist_name,
                    "nationality": nationality,
                    "role": role,
                    "birth": birth,
                    "death": death,
                    "location": location,
                    "title": "; ".join(titles),
                    "classification": "; ".join(classifications),
                    "rightsStatement": "; ".join(rights_statements),
                    "workID": work_id,
                    "repositoryName": repository_name,
                    "recordID": record_id,
                    "recordLinks": record_links,
                    "eventType": event_type,
                    "displayMaterialsTech": display_materials,
                    "inscriptions": inscriptions,
                    "relatedWorkNotes": related_work_notes
                })

# Convert to DataFrame and save to CSV
df = pd.DataFrame(data)
df.replace("", np.nan, inplace=True)
df.to_csv(output_csv, index=False, encoding="utf-8")
# Out:
# /var/folders/23/4_gcwqls3ysbrct5y4v0j9zm0000gn/T/ipykernel_6710/1512842949.py:84: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace("", np.nan, inplace=True)

# %%
import pandas as pd

# Output CSV file path
output_csv = "../output_csv/bremen_output.csv"

# Load and display the CSV as a table
df_bremen = pd.read_csv(output_csv)
df_bremen.head(20)
# Out:
#                  lidoRecordId  \
# 0    DE-MUS-027614/lido/94265
# 1    DE-MUS-027614/lido/84536
# 2    DE-MUS-027614/lido/84537
# 3    DE-MUS-027614/lido/13286
# 4    DE-MUS-027614/lido/54019
# 5    DE-MUS-027614/lido/94199
# 6    DE-MUS-027614/lido/54018
# 7    DE-MUS-027614/lido/94198
# 8    DE-MUS-027614/lido/58959
# 9    DE-MUS-027614/lido/58958
# 10   DE-MUS-027614/lido/82551
# 11   DE-MUS-027614/lido/82550
# 12   DE-MUS-027614/lido/83357
# 13   DE-MUS-027614/lido/39052
# 14  DE-MUS-027614/lido/112311
# 15   DE-MUS-027614/lido/23770
# 16  DE-MUS-027614/lido/112310
# 17   DE-MUS-027614/lido/23771
# 18   DE-MUS-027614/lido/26801
# 19   DE-MUS-027614/lido/87182
#
#                                              imageUrl  \
# 0   https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 1   https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 2   https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 3   https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 4   https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 5   https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 6   https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 7   https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 8   https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 9   https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 10  https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 11  https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 12  https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 13  https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 14  https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 15  https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 16  https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 17  https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 18  https://onlinekatalog.kunsthalle-bremen.de/DE-...
# 19  https://onlinekatalog.kunsthalle-bremen.de/DE-...
#
#                           type  \
# 0   Druckgraphik; Druckgraphik
# 1   Druckgraphik; Druckgraphik
# 2   Druckgraphik; Druckgraphik
# 3   Druckgraphik; Druckgraphik
# 4   Druckgraphik; Druckgraphik
# 5   Druckgraphik; Druckgraphik
# 6   Druckgraphik; Druckgraphik
# 7   Druckgraphik; Druckgraphik
# 8   Druckgraphik; Druckgraphik
# 9   Druckgraphik; Druckgraphik
# 10  Druckgraphik; Druckgraphik
# 11  Druckgraphik; Druckgraphik
# 12  Druckgraphik; Druckgraphik
# 13              Skizze; Skizze
# 14  Druckgraphik; Druckgraphik
# 15  Druckgraphik; Druckgraphik
# 16  Druckgraphik; Druckgraphik
['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    94265
# 1   ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    84536
# 2   ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    84537
# 3   ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    13286
# 4   ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    54019
# 5   ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    94199
# 6   ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    54018
# 7   ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    94198
# 8   ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    58959
# 9   ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    58958
# 10  ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    82551
# 11  ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    82550
# 12  ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    83357
# 13  ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    39052
# 14  ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...   112311
# 15  ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    23770
# 16  ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...   112310
# 17  ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    23771
# 18  ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    26801
# 19  ['Kunsthalle Bremen', 'Bremen, Kunsthalle Brem...    87182
#
#                                           recordLinks    eventType  \
# 0   ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 1   ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 2   ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 3   ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 4   ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 5   ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 6   ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 7   ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 8   ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 9   ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 10  ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 11  ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 12  ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 13  ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 14  ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 15  ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 16  ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 17  ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 18  ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
# 19  ['https://onlinekatalog.kunsthalle-bremen.de/D...  Herstellung
#
#                                  displayMaterialsTech  \
# 0                                     ['Holzschnitt']
# 1                       ['Lithographie, Chine collé']
# 2                                    ['Lithographie']
# 3                   ['Radierung und wenig Kaltnadel']
# 4                                     ['Holzschnitt']
# 5                                    ['Lithographie']
# 6                        ['Holzschnitt', 'Meder 259']
# 7                                    ['Lithographie']
# 8                                     ['Kupferstich']
# 9                                     ['Kupferstich']
# 10                                   ['Lithographie']
# 11                                      ['Radierung']
# 12                      ['Lithographie, Chine collé']
# 13                        ['Pinsel in Grau und Rosa']
# 14                               ['Farblithographie']
# 15                                    ['Kupferstich']
# 16                      ['Lithographie, Chine collé']
# 17                                    ['Kupferstich']
# 18                                    ['Kupferstich']
# 19  ['Punktierstich in Crayonmanier und Aquatinta ...
#
#                                          inscriptions  relatedWorkNotes
# 0   ['oben außerhalb der Darstellung bezeichnet', ...                []
# 1   ['rechts oberhalb der Darstellung nummeriert',...                []
# 2   ['unten links außerhalb der Darstellung: Präge...                []
# 3   ['verso: Kunsthalle Bremen; Lugt 292', 'unten ...                []
# 4   ['verso: Kunsthalle Bremen; Lugt 292', 'unten ...                []
# 5   ['links unterhalb der Darstellung mit "Copie" ...                []
# 6                       ['unten Mitte monogrammiert']                []
# 7   ['Mitte unterhalb der Darstellung von fremder ...                []
# 8   ['oben Mitte innerhalb der Bogenöffnung bezeic...                []
# 9       ['unten rechts auf dem Sarkophag bezeichnet']                []
# 10  ['rechts oberhalb der Darstellung nummeriert',...                []
# 11  ['Mitte rechts innerhalb der Darstellung betit...                []
# 12  ['rechts oberhalb der Darstellung nummeriert',...                []
# 13                                   ['unbezeichnet']                []
# 14  ['oben Mitte oberhalb der Darstellung mit gedr...                []
# 15  ['unten rechts: Johann Heinrich Albers; Lugt 2...                []
# 16  ['unten links unterhalb der Darstellung mit ge...                []
# 17  ['umlaufend im ovalen Rahmen betitelt', 'unten...                []
# 18  ['links unterhalb der Darstellung bezeichnet',...                []
# 19  ['verso: Kunsthalle Bremen; Lugt 292', 'verso:...                []
#
# [20 rows x 25 columns]
